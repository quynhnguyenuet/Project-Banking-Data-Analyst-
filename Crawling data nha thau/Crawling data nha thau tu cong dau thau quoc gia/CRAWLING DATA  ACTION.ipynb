# %%
import ipynb
# %run USER_PASSWORD.ipynb
print('Which job do you want to do?',
      'Job 1. Crawling new data',
      'Job 2. Updating new data',
      'Job 3. Crawling list of constructors',
      sep='\n')

Job_list = ['1', '2', '3']
Job = input('Please input your job (1 / 2 / 3) ------->  ').strip()

while Job not in Job_list:
    print('SORRY!!! Your job is wrong, please input again')
    Job = input('Please input your job (1 / 2 / 3) ------->  ').strip()

print('You chose Job:', Job)
if Job == '1':
    # %run KEO_SRC_THONG_TIN_GOI_THAU.ipynb
if Job == '2':
    # %run UPDATE_SRC_TO_DIM.ipynb
if Job == '3':                                                                                                                                       
    # %run KEO_MA_DINH_DANH_NHA_THAU.ipynb
# Out:
# Please input your user name: quynhnt3
# ----------------------------------------------------
# Please input your pass word: 28082001
# HI 🎉✨🎁🎈
# Quỳnh 🎀
# WELCOME TO THE WORLD OF DATA
# Which job do you want to do?
# Job 1. Crawling new data
# Job 2. Updating new data
# Job 3. Crawling list of constructors
# Please input your job (1 / 2 / 3) ------->  2
# You chose Job: 2
# Hi you are working to update data from DIM_OVERVIEW to SRC_DETAIL
# Please choose the step do you want to run:
# Step 1. Exporting data from database SME to local
# Step 2. Crawling data from website to insert to your local
# Step 3. Exporting data from your local to database SME
# Please input your step (1 / 2 / 3 / 1 2 3 / 1 2 / 2 3) ------->  2
# You chose step: 2
# Please input your user name: quynhnt3
# ----------------------------------------------------
# Please input your pass word: 28082001
# HI 🎉✨🎁🎈
# Quỳnh 🎀
# WELCOME TO THE WORLD OF DATA
# is your local: LT32046SME200
# ...
