# %%
import ipynb
# %run USER_PASSWORD.ipynb
print('Which job do you want to do?','Job 1. Crawling new data','Job 2. Updating new data','Job 3. Crawling list of constructors',sep = '\n')
job = input(str('Please input your job(Job 1/Job 2/Job 3): ------> '))
if job == 'Job 1':
    # %run KEO_SRC_THONG_TIN_GOI_THAU.ipynb
if job == 'Job 2':
    # %run UPDATE_SRC_TO_DIM.ipynb
if job == 'Job 3':                                                                                                                                       
    # %run KEO_MA_DINH_DANH_NHA_THAU.ipynb
# Out:
# SORRY!!! Your user name is invalid, please input again
# Please input your user name: taimx
# ----------------------------------------------------
# SORRY!!! Your pass word is wrong, please input again
# Please input your pass word: A12345
# ----------------------------------------------------
# HI!!!!!!!!!!
# taimx
# WELCOME TO THE WORLD OF DATA
# Which job do you want to do?
# Job 1. Crawling new data
# Job 2. Updating new data
# Job 3. Crawling list of constructors
# Please input your job(Job 1/Job 2/Job 3): ------> Job 1
# Please make sure to use LAN connection to do this job
# -----------------------------------------------------------------
#
# Do you want to delete table TAIMX_SRC_DU_LIEU_GOI_THAU_OVERVIEW before crawling new data(Yes/No): No
# What do you want to crawl??
#  1.--->   Đang mở thầu
#  2.--->   Đang xét thầu
#  3.--->   Đã trúng thầu
#  4.--->   All
#  5.--->   Skip this step
# INCORRECT!!!!, Your choice is invalid, please make it again!!
# ...
